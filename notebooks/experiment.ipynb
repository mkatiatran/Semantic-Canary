# %% [markdown]
# # SemanticCanary experiment
# Run the CLI benchmark first, then inspect `artifacts/benchmark.json`.

# %%
from semantic_canary.data import load_claims
df = load_claims(rows=10000)
df.head()

# %%
from semantic_canary.failures import scenarios
failures = scenarios(df.iloc[len(df)//2:].copy())
list(failures)
